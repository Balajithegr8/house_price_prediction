# %%
import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
    
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.401822e+05  3.673622e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap="RdBu")
plt.title("Correlations Between Variables", size=15)
plt.show()

# %%
df['bedrooms'].value_counts().plot(kind="bar")
plt.title("Number of bedrooms")
plt.xlabel("bedrooms")
plt.ylabel("count")
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=df.lat.values, y=df.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df.price,df.sqft_living)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(df.price,df.long)
plt.title("Price vs Location")
# Out:
# Text(0.5, 1.0, 'Price vs Location')

# %%
plt.scatter(df.price,df.lat)
plt.title("Price vs Latitude")
# Out:
# Text(0.5, 1.0, 'Price vs Latitude')

# %%
plt.scatter(df.bedrooms,df.price)
plt.title("Bedrooms vs price")
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df.zipcode,df.price)
plt.title("Which locations are more expensive due to Zipcode")
plt.ylabel("price")
plt.xlabel("Zipcode")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
lab = df['price']
conv_dates = [1 if values == 2014 else 0 for values in df.date ]
df['date'] = conv_dates
train_data = df.drop(['id', 'price'],axis=1)
print(train_data)
# Out:
#        date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0         0         3       1.00         1180      5650     1.0           0
# 1         0         3       2.25         2570      7242     2.0           0
# 2         0         2       1.00          770     10000     1.0           0
# 3         0         4       3.00         1960      5000     1.0           0
# 4         0         3       2.00         1680      8080     1.0           0
# ...     ...       ...        ...          ...       ...     ...         ...
# 21608     0         3       2.50         1530      1131     3.0           0
# 21609     0         4       2.50         2310      5813     2.0           0
# 21610     0         2       0.75         1020      1350     2.0           0
# 21611     0         3       2.50         1600      2388     2.0           0
# 21612     0         2       0.75         1020      1076     2.0           0
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(train_data , lab , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pickle.dump(reg, open('model.pkl','wb'))

# %%
reg.score(x_test,y_test)
# Out:
# 0.7320721056068176

# %% [markdown]
# Hmm,accuracy seems low ,less than 85% is not considered real life applicable. let's apply some gradient descent

# %%
from sklearn import ensemble
cf=ensemble.GradientBoostingRegressor(n_estimators=400,max_depth=5,min_samples_split=2,learning_rate=0.1,loss='squared_error')

# %%
cf.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
cf.score(x_test,y_test)
# Out:
# 0.9211070534437218

# %% [markdown]
# Now this is acceptable 92%

# %%
cf=ensemble.GradientBoostingRegressor(n_estimators=1000,max_depth=5,min_samples_split=2,learning_rate=0.07,loss='huber')

# %%
cf.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.07, loss='huber', max_depth=5,
#                           n_estimators=1000)

# %%
cf.score(x_test,y_test)
# Out:
# 0.9188748657677084

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
print(model.predict([[20141013,3,1,1180,5650,1,0,0,3,7,1180,0,1955,0,98178,47.5112,-122.257,1340,5650]]))
# Out:
# [208998.7660498]
